# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os


base_dir = 'Datasets'
train_dir = 'Datasets/train'
test_dir = 'Datasets/test'
train_pumba_dir = 'Datasets/train/pumba'
train_surik_dir = 'Datasets/train/surik'
test_pumba_dir = 'Datasets/test/pumba'
test_surik_dir = 'Datasets/test/surik'


pumba_tr = len(os.listdir(train_pumba_dir))
surik_tr = len(os.listdir(train_surik_dir))
pumba_test = len(os.listdir(test_pumba_dir))
surik_test = len(os.listdir(test_surik_dir))
total_test = pumba_test + surik_test
total_train = pumba_tr + surik_tr

print('Кабанов в учебном наборе данных: ', pumba_tr)
print('Сурикатов в учебном наборе данных: ', surik_tr)
print('Кабанов в тестовом наборе данных: ', pumba_test)
print('Сурикатов в тестовом наборе данных: ', surik_test)
print('Животных в учебном наборе данных: ', total_train)
print('Животных в тестовом наборе данных: ', total_test)

IMG_SHAPE = 80 # размерность 80x80

image_generator_1 = ImageDataGenerator(rescale=1./255)
image_generator_2 = ImageDataGenerator(rescale=1./255, rotation_range=45, vertical_flip=True)
image_generator_3 = ImageDataGenerator(rescale=1./255, rotation_range=30)
image_generator_4 = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen_1 = image_generator_1.flow_from_directory(batch_size=total_train,
                                                          directory=train_dir,
                                                          shuffle=True,
                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                          class_mode="binary")
train_data_gen_2 = image_generator_2.flow_from_directory(batch_size=total_train,
                                                          directory=train_dir,
                                                          shuffle=True,
                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                          class_mode="binary")
train_data_gen_3 = image_generator_3.flow_from_directory(batch_size=total_train,
                                                          directory=train_dir,
                                                          shuffle=True,
                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                          class_mode="binary")
train_data_gen_4 = image_generator_4.flow_from_directory(batch_size=total_train,
                                                          directory=train_dir,
                                                          shuffle=True,
                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                          class_mode="binary")
                                                          
print(train_data_gen_1.class_indices) #проверка классов для обучения
print(train_data_gen_2.class_indices)
print(train_data_gen_3.class_indices)
print(train_data_gen_4.class_indices)

test_data_gen_1 = image_generator_1.flow_from_directory(batch_size=total_test,
                                                              directory=test_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE),
                                                              class_mode="binary")
test_data_gen_2 = image_generator_2.flow_from_directory(batch_size=total_test,
                                                              directory=test_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE),
                                                              class_mode="binary")
test_data_gen_3 = image_generator_3.flow_from_directory(batch_size=total_test,
                                                              directory=test_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE),
                                                              class_mode="binary")
test_data_gen_4 = image_generator_4.flow_from_directory(batch_size=total_test,
                                                              directory=test_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE),
                                                              class_mode="binary")
                                                              
print(test_data_gen_1.class_indices) #проверка классов для теста
print(test_data_gen_2.class_indices)
print(test_data_gen_3.class_indices)
print(test_data_gen_4.class_indices)


train_images_1, train_labels_1 = next(train_data_gen_1)
train_images_2, train_labels_2 = next(train_data_gen_2)
train_images_3, train_labels_3 = next(train_data_gen_3)
train_images_4, train_labels_4 = next(train_data_gen_4)

train_images = np.concatenate((train_images_1, train_images_2))
train_images = np.concatenate((train_images, train_images_3))
train_images = np.concatenate((train_images, train_images_4))

train_labels = np.concatenate((train_labels_1, train_labels_2))
train_labels = np.concatenate((train_labels, train_labels_4))
train_labels = np.concatenate((train_labels, train_labels_4))


test_images_1, test_labels_1 = next(test_data_gen_1)
test_images_2, test_labels_2 = next(test_data_gen_2)
test_images_3, test_labels_3 = next(test_data_gen_3)
test_images_4, test_labels_4 = next(test_data_gen_4)

test_images = np.concatenate((test_images_1, test_images_2))
test_images = np.concatenate((test_images, test_images_3))
test_images = np.concatenate((test_images, test_images_4))

test_labels = np.concatenate((test_labels_1, test_labels_2))
test_labels = np.concatenate((test_labels, test_labels_2))
test_labels = np.concatenate((test_labels, test_labels_4))

class_names = np.array(['Pumba', 'Timon'])


#____________________________________________________________
#Output обучающие данные с подписями
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[int(str(train_labels[i])[0])])
plt.show()
#____________________________________________________________

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (5,5), activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (5, 5), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(128, (5, 5), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(512, (5, 5), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01, momentum=0.25, nesterov=False),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

model.fit(train_images, train_labels, epochs=110) #Обучение

predictions = model.predict(test_images) #Предсказания
#____________________________________________________________
#Output тестовые данные с подписями(предсказаниями)
plt.figure(figsize=(20,20))
for i in range(50):
    plt.subplot(10,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(predictions[i])])
plt.show()
#____________________________________________________________

TP = 0
TN = 0
FP = 0
FN = 0
i = 0
while i < len(test_labels):
    if str(test_labels[i])[0] == '1' and str(np.argmax(predictions[i])) == '1':
        TP += 1
    elif str(test_labels[i])[0] == '1' and str(np.argmax(predictions[i])) == '0':
        FN += 1
    elif str(test_labels[i])[0] == '0' and str(np.argmax(predictions[i])) == '1':
        FP += 1
    elif str(test_labels[i])[0] == '0' and str(np.argmax(predictions[i])) == '0':
        TN += 1
    i += 1
    
Accuracy = (TN + TP) / (TN + FP + FN + TP)
Precision = TP / (FP + TP)
Sensitivity = TP / (TP + FN)
Specificity = TN / (TN + FP)


print("TP:", TP)
print("TN:", TN)
print("FP:", FP)
print("FN:", FN)
print("\nAccuracy:", Accuracy)
print("Precision:", Precision)
print("Sensitivity:", Sensitivity)
print("Specificity:", Specificity)
# Out:
# Кабанов в учебном наборе данных:  187
# Сурикатов в учебном наборе данных:  181
# Кабанов в тестовом наборе данных:  30
# Сурикатов в тестовом наборе данных:  30
# Животных в учебном наборе данных:  368
# Животных в тестовом наборе данных:  60
# Found 367 images belonging to 2 classes.
# Found 367 images belonging to 2 classes.
# Found 367 images belonging to 2 classes.
# Found 367 images belonging to 2 classes.
# {'pumba': 0, 'surik': 1}
# {'pumba': 0, 'surik': 1}
# {'pumba': 0, 'surik': 1}
# {'pumba': 0, 'surik': 1}
# Found 60 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.
# {'pumba': 0, 'surik': 1}
# {'pumba': 0, 'surik': 1}
# {'pumba': 0, 'surik': 1}
# {'pumba': 0, 'surik': 1}
# /home/vladislav/1cloud/1cloud/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:788: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 76, 76, 32)        2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 38, 38, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 34, 34, 64)        51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 128)       204928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 512)         1638912
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 2,161,218
# Trainable params: 2,161,218
# Non-trainable params: 0
# _________________________________________________________________
# Train on 1468 samples
# Epoch 1/110
# 1468/1468 [==============================] - 38s 26ms/sample - loss: 0.6909 - accuracy: 0.5429
# Epoch 2/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.6854 - accuracy: 0.6029
# Epoch 3/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.6810 - accuracy: 0.6029
# Epoch 4/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.6717 - accuracy: 0.5947
# Epoch 5/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.6550 - accuracy: 0.6396
# Epoch 6/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.6467 - accuracy: 0.6492
# Epoch 7/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.6232 - accuracy: 0.6567
# Epoch 8/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.6153 - accuracy: 0.6846
# Epoch 9/110
# 1468/1468 [==============================] - 35s 24ms/sample - loss: 0.5960 - accuracy: 0.6969
# Epoch 10/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.5689 - accuracy: 0.7207
# Epoch 11/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.5574 - accuracy: 0.7289
# Epoch 12/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.5424 - accuracy: 0.7480
# Epoch 13/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.5341 - accuracy: 0.7473
# Epoch 14/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.5201 - accuracy: 0.7527
# Epoch 15/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.5073 - accuracy: 0.7670
# Epoch 16/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.4946 - accuracy: 0.7772
# Epoch 17/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.4911 - accuracy: 0.7841
# Epoch 18/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4979 - accuracy: 0.7793
# Epoch 19/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4826 - accuracy: 0.7807
# Epoch 20/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4775 - accuracy: 0.7875
# Epoch 21/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4731 - accuracy: 0.7902
# Epoch 22/110
# 1468/1468 [==============================] - 36s 24ms/sample - loss: 0.4678 - accuracy: 0.7984
# Epoch 23/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4648 - accuracy: 0.7916
# Epoch 24/110
# 1468/1468 [==============================] - 35s 24ms/sample - loss: 0.4605 - accuracy: 0.7956
# Epoch 25/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4493 - accuracy: 0.8031
# Epoch 26/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4518 - accuracy: 0.8004
# Epoch 27/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.4508 - accuracy: 0.8052
# Epoch 28/110
# 1468/1468 [==============================] - 35s 24ms/sample - loss: 0.4421 - accuracy: 0.8222
# Epoch 29/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.4325 - accuracy: 0.8134
# Epoch 30/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.4341 - accuracy: 0.8086
# Epoch 31/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4332 - accuracy: 0.8215
# Epoch 32/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.4328 - accuracy: 0.8147
# Epoch 33/110
# 1468/1468 [==============================] - 38s 26ms/sample - loss: 0.4263 - accuracy: 0.8208
# Epoch 34/110
# 1468/1468 [==============================] - 38s 26ms/sample - loss: 0.4225 - accuracy: 0.8317
# Epoch 35/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.4280 - accuracy: 0.8181
# Epoch 36/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4102 - accuracy: 0.8365
# Epoch 37/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.4083 - accuracy: 0.8317
# Epoch 38/110
# 1468/1468 [==============================] - 41s 28ms/sample - loss: 0.4073 - accuracy: 0.8365
# Epoch 39/110
# 1468/1468 [==============================] - 42s 29ms/sample - loss: 0.3995 - accuracy: 0.8351
# Epoch 40/110
# 1468/1468 [==============================] - 53s 36ms/sample - loss: 0.3933 - accuracy: 0.8297
# Epoch 41/110
# 1468/1468 [==============================] - 51s 35ms/sample - loss: 0.3888 - accuracy: 0.8392
# Epoch 42/110
# 1468/1468 [==============================] - 36s 25ms/sample - loss: 0.3862 - accuracy: 0.8426
# Epoch 43/110
# 1468/1468 [==============================] - 41s 28ms/sample - loss: 0.3824 - accuracy: 0.8515
# Epoch 44/110
# 1468/1468 [==============================] - 48s 33ms/sample - loss: 0.3761 - accuracy: 0.8467
# Epoch 45/110
# 1468/1468 [==============================] - 50s 34ms/sample - loss: 0.3757 - accuracy: 0.8535
# Epoch 46/110
# 1468/1468 [==============================] - 49s 34ms/sample - loss: 0.3695 - accuracy: 0.8440
# Epoch 47/110
# 1468/1468 [==============================] - 39s 26ms/sample - loss: 0.3568 - accuracy: 0.8576
# Epoch 48/110
# 1468/1468 [==============================] - 31s 21ms/sample - loss: 0.3549 - accuracy: 0.8597
# Epoch 49/110
# 1468/1468 [==============================] - 41s 28ms/sample - loss: 0.3468 - accuracy: 0.8638
# Epoch 50/110
# 1468/1468 [==============================] - 49s 33ms/sample - loss: 0.3386 - accuracy: 0.8617
# Epoch 51/110
# 1468/1468 [==============================] - 47s 32ms/sample - loss: 0.3368 - accuracy: 0.8617
# Epoch 52/110
# 1468/1468 [==============================] - 32s 21ms/sample - loss: 0.3339 - accuracy: 0.8692
# Epoch 53/110
# 1468/1468 [==============================] - 31s 21ms/sample - loss: 0.3212 - accuracy: 0.8774
# Epoch 54/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.3037 - accuracy: 0.8781
# Epoch 55/110
# 1468/1468 [==============================] - 48s 32ms/sample - loss: 0.3170 - accuracy: 0.8760
# Epoch 56/110
# 1468/1468 [==============================] - 49s 34ms/sample - loss: 0.3056 - accuracy: 0.8760
# Epoch 57/110
# 1468/1468 [==============================] - 50s 34ms/sample - loss: 0.2969 - accuracy: 0.8787
# Epoch 58/110
# 1468/1468 [==============================] - 47s 32ms/sample - loss: 0.2884 - accuracy: 0.8828
# Epoch 59/110
# 1468/1468 [==============================] - 38s 26ms/sample - loss: 0.2899 - accuracy: 0.8951
# Epoch 60/110
# 1468/1468 [==============================] - 38s 26ms/sample - loss: 0.2615 - accuracy: 0.8917
# Epoch 61/110
# 1468/1468 [==============================] - 39s 26ms/sample - loss: 0.2482 - accuracy: 0.8937
# Epoch 62/110
# 1468/1468 [==============================] - 38s 26ms/sample - loss: 0.2537 - accuracy: 0.8965
# Epoch 63/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.2239 - accuracy: 0.9176
# Epoch 64/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.2189 - accuracy: 0.9128
# Epoch 65/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.2401 - accuracy: 0.9053
# Epoch 66/110
# 1468/1468 [==============================] - 48s 32ms/sample - loss: 0.2193 - accuracy: 0.9135
# Epoch 67/110
# 1468/1468 [==============================] - 48s 33ms/sample - loss: 0.2074 - accuracy: 0.9217
# Epoch 68/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.2170 - accuracy: 0.9196
# Epoch 69/110
# 1468/1468 [==============================] - 32s 22ms/sample - loss: 0.1746 - accuracy: 0.9326
# Epoch 70/110
# 1468/1468 [==============================] - 32s 22ms/sample - loss: 0.2080 - accuracy: 0.9217
# Epoch 71/110
# 1468/1468 [==============================] - 31s 21ms/sample - loss: 0.1792 - accuracy: 0.9278
# Epoch 72/110
# 1468/1468 [==============================] - 32s 22ms/sample - loss: 0.1757 - accuracy: 0.9319
# Epoch 73/110
# 1468/1468 [==============================] - 31s 21ms/sample - loss: 0.1872 - accuracy: 0.9285
# Epoch 74/110
# 1468/1468 [==============================] - 32s 22ms/sample - loss: 0.1430 - accuracy: 0.9435
# Epoch 75/110
# 1468/1468 [==============================] - 46s 31ms/sample - loss: 0.1609 - accuracy: 0.9298
# Epoch 76/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.1795 - accuracy: 0.9339
# Epoch 77/110
# 1468/1468 [==============================] - 46s 31ms/sample - loss: 0.1256 - accuracy: 0.9544
# Epoch 78/110
# 1468/1468 [==============================] - 46s 31ms/sample - loss: 0.1321 - accuracy: 0.9503
# Epoch 79/110
# 1468/1468 [==============================] - 46s 32ms/sample - loss: 0.1513 - accuracy: 0.9394
# Epoch 80/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.1039 - accuracy: 0.9646
# Epoch 81/110
# 1468/1468 [==============================] - 45s 30ms/sample - loss: 0.1329 - accuracy: 0.9510
# Epoch 82/110
# 1468/1468 [==============================] - 46s 31ms/sample - loss: 0.1034 - accuracy: 0.9605
# Epoch 83/110
# 1468/1468 [==============================] - 49s 33ms/sample - loss: 0.2460 - accuracy: 0.9087
# Epoch 84/110
# 1468/1468 [==============================] - 46s 31ms/sample - loss: 0.2334 - accuracy: 0.9074
# Epoch 85/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.1084 - accuracy: 0.9605
# Epoch 86/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.0931 - accuracy: 0.9687
# Epoch 87/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.1158 - accuracy: 0.9550
# Epoch 88/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0920 - accuracy: 0.9625
# Epoch 89/110
# 1468/1468 [==============================] - 45s 30ms/sample - loss: 0.0671 - accuracy: 0.9762
# Epoch 90/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.0899 - accuracy: 0.9659
# Epoch 91/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.0660 - accuracy: 0.9768
# Epoch 92/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0662 - accuracy: 0.9796
# Epoch 93/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0686 - accuracy: 0.9741
# Epoch 94/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0943 - accuracy: 0.9639
# Epoch 95/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0636 - accuracy: 0.9802
# Epoch 96/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0594 - accuracy: 0.9796
# Epoch 97/110
# 1468/1468 [==============================] - 43s 30ms/sample - loss: 0.0505 - accuracy: 0.9843
# Epoch 98/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0551 - accuracy: 0.9789
# Epoch 99/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.0563 - accuracy: 0.9802
# Epoch 100/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.0389 - accuracy: 0.9871
# Epoch 101/110
# 1468/1468 [==============================] - 47s 32ms/sample - loss: 0.0628 - accuracy: 0.9755
# Epoch 102/110
# 1468/1468 [==============================] - 45s 31ms/sample - loss: 0.0545 - accuracy: 0.9809
# Epoch 103/110
# 1468/1468 [==============================] - 45s 30ms/sample - loss: 0.0533 - accuracy: 0.9802
# Epoch 104/110
# 1468/1468 [==============================] - 44s 30ms/sample - loss: 0.0491 - accuracy: 0.9843
# Epoch 105/110
# 1468/1468 [==============================] - 46s 31ms/sample - loss: 0.0438 - accuracy: 0.9857
# Epoch 106/110
# 1468/1468 [==============================] - 45s 30ms/sample - loss: 0.0396 - accuracy: 0.9830
# Epoch 107/110
# 1468/1468 [==============================] - 43s 30ms/sample - loss: 0.0423 - accuracy: 0.9871
# Epoch 108/110
# 1468/1468 [==============================] - 37s 25ms/sample - loss: 0.0334 - accuracy: 0.9891
# Epoch 109/110
# 1468/1468 [==============================] - 35s 24ms/sample - loss: 0.0738 - accuracy: 0.9721
# Epoch 110/110
# 1468/1468 [==============================] - 41s 28ms/sample - loss: 0.0409 - accuracy: 0.9830
# TP: 104
# TN: 114
# FP: 6
# FN: 16
#
# Accuracy: 0.9083333333333333
# Precision: 0.9454545454545454
# Sensitivity: 0.8666666666666667
# Specificity: 0.95

# %%
model.save("BinaryClassifier_model_91.h5")
